# %% [markdown]
# # Obligatorio 2 - Big Data Science
#
# Integrantes del grupo: [completar aquí los nombres de los integrantes]
#
# Debajo de cada pregunta o tarea incluya las celdas necesarias para desarrolar la respuesta. Puede usar una o varias celdas de código o mark down (https://www.datacamp.com/community/tutorials/markdown-in-jupyter-notebook)
#
# Para entregar, renombrar este notebook como "Obligatorio 2 - Apellido1 - Apellido 2 - Apellido 3" con los apellidos de los miembros del grupo. Un solo integrante del grupo debe realizar la entrega.

# %% [markdown]
# 1. Cargar los datos del Obligatorio 1, de entrenamiento (.data) y validación (.test) en spark dataframes (distintos). Los nombres de las columnas deben corresponder a los especificados en "Attribute Information".

# %%
from pyspark.context import SparkContext
sc = SparkContext('local', 'test')

# %%
sc
# Out:
# <SparkContext master=local appName=test>

# %%
from pyspark.sql import SQLContext

spark = SQLContext(sc)

# %%
spark

# %%
from pyspark.sql.types import *

# Schema de los dataset
schema = StructType([
    StructField(name='age', dataType=IntegerType(), nullable=False),
    StructField(name='workclass', dataType=StringType(), nullable=False),
    StructField(name='fnlwgt', dataType=StringType(), nullable=False), # Se pone en tipo string porque al ponerlo en tipo Integer o Long carga la columna con valores null
    StructField(name='education', dataType=StringType(), nullable=False),
    StructField(name='education_num', dataType=StringType(), nullable=False), # Mismo problema que en la columna 'fnlwgt'
    StructField(name='marital-status', dataType=StringType(), nullable=False),
    StructField(name='occupation', dataType=StringType(), nullable=False),
    StructField(name='relationship', dataType=StringType(), nullable=False),
    StructField(name='race', dataType=StringType(), nullable=False),
    StructField(name='sex', dataType=StringType(), nullable=False),
    StructField(name='capital_gain', dataType=StringType(), nullable=False), # Mismo problema que en la columna 'fnlwgt'
    StructField(name='capital_loss', dataType=StringType(), nullable=False), # Mismo problema que en la columna 'fnlwgt'
    StructField(name='hours_per_week', dataType=StringType(), nullable=False), # Mismo problema que en la columna 'fnlwgt'
    StructField(name='native_country', dataType=StringType(), nullable=False),
    StructField(name='income', dataType=StringType(), nullable=False)
])

# %%
df_adult = spark.read.csv("adult.data", header=True, schema=schema)
df_test = spark.read.csv("adult.test", header=True, schema=schema) # sacamos el punto del archivo adult.test

# %%
df_adult.show(10)
# Out:
# +---+-----------------+-------+-------------+-------------+--------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+
# |age|        workclass| fnlwgt|    education|education_num|      marital-status|        occupation|  relationship|  race|    sex|capital_gain|capital_loss|hours_per_week|native_country|income|
# +---+-----------------+-------+-------------+-------------+--------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+
# | 50| Self-emp-not-inc|  83311|    Bachelors|           13|  Married-civ-spouse|   Exec-managerial|       Husband| White|   Male|           0|           0|            13| United-States| <=50K|
# | 38|          Private| 215646|      HS-grad|            9|            Divorced| Handlers-cleaners| Not-in-family| White|   Male|           0|           0|            40| United-States| <=50K|
# | 53|          Private| 234721|         11th|            7|  Married-civ-spouse| Handlers-cleaners|       Husband| Black|   Male|           0|           0|            40| United-States| <=50K|
# | 28|          Private| 338409|    Bachelors|           13|  Married-civ-spouse|    Prof-specialty|          Wife| Black| Female|           0|           0|            40|          Cuba| <=50K|
# | 37|          Private| 284582|      Masters|           14|  Married-civ-spouse|   Exec-managerial|          Wife| White| Female|           0|           0|            40| United-States| <=50K|
# | 49|          Private| 160187|          9th|            5| Married-spouse-a...|     Other-service| Not-in-family| Black| Female|           0|           0|            16|       Jamaica| <=50K|
# | 52| Self-emp-not-inc| 209642|      HS-grad|            9|  Married-civ-spouse|   Exec-managerial|       Husband| White|   Male|           0|           0|            45| United-States|  >50K|
# | 31|          Private|  45781|      Masters|           14|       Never-married|    Prof-specialty| Not-in-family| White| Female|       14084|           0|            50| United-States|  >50K|
# | 42|          Private| 159449|    Bachelors|           13|  Married-civ-spouse|   Exec-managerial|       Husband| White|   Male|        5178|           0|            40| United-States|  >50K|
# | 37|          Private| 280464| Some-college|           10|  Married-civ-spouse|   Exec-managerial|       Husband| Black|   Male|           0|           0|            80| United-States|  >50K|
# +---+-----------------+-------+-------------+-------------+--------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+
# only showing top 10 rows

# %%
df_test.show(10)
# Out:
# +---+-----------------+-------+-------------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+
# |age|        workclass| fnlwgt|    education|education_num|     marital-status|        occupation|  relationship|  race|    sex|capital_gain|capital_loss|hours_per_week|native_country|income|
# +---+-----------------+-------+-------------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+
# | 38|          Private|  89814|      HS-grad|            9| Married-civ-spouse|   Farming-fishing|       Husband| White|   Male|           0|           0|            50| United-States| <=50K|
# | 28|        Local-gov| 336951|   Assoc-acdm|           12| Married-civ-spouse|   Protective-serv|       Husband| White|   Male|           0|           0|            40| United-States|  >50K|
# | 44|          Private| 160323| Some-college|           10| Married-civ-spouse| Machine-op-inspct|       Husband| Black|   Male|        7688|           0|            40| United-States|  >50K|
# | 18|                ?| 103497| Some-college|           10|      Never-married|                 ?|     Own-child| White| Female|           0|           0|            30| United-States| <=50K|
# | 34|          Private| 198693|         10th|            6|      Never-married|     Other-service| Not-in-family| White|   Male|           0|           0|            30| United-States| <=50K|
# | 29|                ?| 227026|      HS-grad|            9|      Never-married|                 ?|     Unmarried| Black|   Male|           0|           0|            40| United-States| <=50K|
# | 63| Self-emp-not-inc| 104626|  Prof-school|           15| Married-civ-spouse|    Prof-specialty|       Husband| White|   Male|        3103|           0|            32| United-States|  >50K|
# | 24|          Private| 369667| Some-college|           10|      Never-married|     Other-service|     Unmarried| White| Female|           0|           0|            40| United-States| <=50K|
# | 55|          Private| 104996|      7th-8th|            4| Married-civ-spouse|      Craft-repair|       Husband| White|   Male|           0|           0|            10| United-States| <=50K|
# | 65|          Private| 184454|      HS-grad|            9| Married-civ-spouse| Machine-op-inspct|       Husband| White|   Male|        6418|           0|            40| United-States|  >50K|
# +---+-----------------+-------+-------------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+
# only showing top 10 rows

# %% [markdown]
# 2. Seleccionar un conjunto relevante de 5 atributos y crear un Spark Pipeline en el que el estimator sea un DecisionTreeClassifier (https://spark.apache.org/docs/latest/ml-classification-regression.html#decision-tree-classifier). Puede utilizar libremente los transformers/estimators de Spark para realizar ingeniería de atributos (StringIndexer, OneHotEncoding, etc).

# %%
atributos = ["age", "sex", "occupation", "education", "workclass"]

#Primero hay que bucketizar la edad. La separamos en 3 buckets. 

def calculo_de_buckets(df, cantidad_buckets, columna):
    df.createOrReplaceTempView("df_view")
    instancias_totales = spark.sql('''SELECT count(*) as count FROM df_view''').first()['count']
    instancias_en_bucket = instancias_totales / cantidad_buckets
    
    limites = []
    ultimo_limite_superior = None
    for limit in range(0, instancias_totales - 1, round(instancias_en_bucket)): # se pone un -1 porque instancias totales es el count pero queremos llegar hasta el indice        
        query = spark.sql(f'''SELECT {columna} FROM df_view ORDER BY 1 asc''').collect()
        limite_inferior = query[limit][columna]
        
        if(ultimo_limite_superior is not None):
            if ultimo_limite_superior == limite_inferior:
                limite_inferior += 1;
        
        limite = [limite_inferior, query[limit + round(instancias_en_bucket)][columna]]
        limites.append(limite)
        
        ultimo_limite_superior = query[limit + round(instancias_en_bucket)][columna]

    return limites

limites = calculo_de_buckets(df_adult, 3, "age")

# %%
from pyspark.sql import functions as F

def age_bucket_udf(age):
    indexes = range(len(limites))
    for index, limite in zip(indexes, limites):
        if age in range(limite[0], limite[1] + 1):    #Se agrega el +1 para hacer el range inclusivo superiormente
            return str(index)

age_udf = F.udf(age_bucket_udf, StringType())

df_adult_bucketized = df_adult.withColumn("ageBucket", age_udf(F.col("age")))
df_test_bucketized = df_test.withColumn("ageBucket", age_udf(F.col("age")))

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.feature import StringIndexer, VectorIndexer, VectorAssembler

# %%
def get_indexers(columnas):
    
    list_indexer = []
    
    for columna in columnas:
        list_indexer.append(StringIndexer(inputCol=columna, outputCol=columna+"Index"))
    
    return list_indexer

# %%
def get_pipeline(
                categoricalColumns=["sex", "occupation", "education", "workclass", "ageBucket"],
                labelCol='income',
                thresholds=None
                ):
    stages = []

    stages += get_indexers([labelCol])

    stages += get_indexers(categoricalColumns)

    assembler_input = [c + "Index" for c in categoricalColumns]

    assembler = VectorAssembler(
        inputCols=assembler_input,
        outputCol="features")

    stages += [assembler]
    
    dt = DecisionTreeClassifier(labelCol=labelCol+"Index", featuresCol="features")
    
    if thresholds:
        dt.setThresholds(thresholds)

    stages += [dt]
    
    return Pipeline(stages=stages)

# %%
pipeline = get_pipeline()

# %% [markdown]
# 3. Hacer el fit del pipeline con los datos de entrenamiento.

# %%
trainingData = df_adult_bucketized
testData = df_test_bucketized

# %%
model = pipeline.fit(trainingData)

# %%
# Analisis extra

# %%
predictions = model.transform(testData)

# %%
predictions.show(10, truncate=False)
# Out:
# +---+-----------------+-------+-------------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+---------+-----------+--------+---------------+--------------+--------------+--------------+----------------------+----------------+----------------------------------------+----------+
# |age|workclass        |fnlwgt |education    |education_num|marital-status     |occupation        |relationship  |race  |sex    |capital_gain|capital_loss|hours_per_week|native_country|income|ageBucket|incomeIndex|sexIndex|occupationIndex|educationIndex|workclassIndex|ageBucketIndex|features              |rawPrediction   |probability                             |prediction|
# +---+-----------------+-------+-------------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+---------+-----------+--------+---------------+--------------+--------------+--------------+----------------------+----------------+----------------------------------------+----------+
# |38 | Private         | 89814 | HS-grad     | 9           | Married-civ-spouse| Farming-fishing  | Husband      | White| Male  | 0          | 0          | 50           | United-States| <=50K|1        |0.0        |0.0     |10.0           |0.0           |0.0           |1.0           |(5,[1,4],[10.0,1.0])  |[20340.0,4014.0]|[0.8351810790835181,0.1648189209164819] |0.0       |
# |28 | Local-gov       | 336951| Assoc-acdm  | 12          | Married-civ-spouse| Protective-serv  | Husband      | White| Male  | 0          | 0          | 40           | United-States| >50K |0        |1.0        |0.0     |12.0           |6.0           |2.0           |0.0           |[0.0,12.0,6.0,2.0,0.0]|[20340.0,4014.0]|[0.8351810790835181,0.1648189209164819] |0.0       |
# |44 | Private         | 160323| Some-college| 10          | Married-civ-spouse| Machine-op-inspct| Husband      | Black| Male  | 7688       | 0          | 40           | United-States| >50K |1        |1.0        |0.0     |6.0            |1.0           |0.0           |1.0           |[0.0,6.0,1.0,0.0,1.0] |[20340.0,4014.0]|[0.8351810790835181,0.1648189209164819] |0.0       |
# |18 | ?               | 103497| Some-college| 10          | Never-married     | ?                | Own-child    | White| Female| 0          | 0          | 30           | United-States| <=50K|0        |0.0        |1.0     |7.0            |1.0           |3.0           |0.0           |[1.0,7.0,1.0,3.0,0.0] |[20340.0,4014.0]|[0.8351810790835181,0.1648189209164819] |0.0       |
# |34 | Private         | 198693| 10th        | 6           | Never-married     | Other-service    | Not-in-family| White| Male  | 0          | 0          | 30           | United-States| <=50K|1        |0.0        |0.0     |5.0            |7.0           |0.0           |1.0           |[0.0,5.0,7.0,0.0,1.0] |[20340.0,4014.0]|[0.8351810790835181,0.1648189209164819] |0.0       |
# |29 | ?               | 227026| HS-grad     | 9           | Never-married     | ?                | Unmarried    | Black| Male  | 0          | 0          | 40           | United-States| <=50K|0        |0.0        |0.0     |7.0            |0.0           |3.0           |0.0           |(5,[1,3],[7.0,3.0])   |[20340.0,4014.0]|[0.8351810790835181,0.1648189209164819] |0.0       |
# |63 | Self-emp-not-inc| 104626| Prof-school | 15          | Married-civ-spouse| Prof-specialty   | Husband      | White| Male  | 3103       | 0          | 32           | United-States| >50K |2        |1.0        |0.0     |0.0            |9.0           |1.0           |2.0           |[0.0,0.0,9.0,1.0,2.0] |[739.0,1927.0]  |[0.27719429857464367,0.7228057014253564]|1.0       |
# |24 | Private         | 369667| Some-college| 10          | Never-married     | Other-service    | Unmarried    | White| Female| 0          | 0          | 40           | United-States| <=50K|0        |0.0        |1.0     |5.0            |1.0           |0.0           |0.0           |[1.0,5.0,1.0,0.0,0.0] |[20340.0,4014.0]|[0.8351810790835181,0.1648189209164819] |0.0       |
# |55 | Private         | 104996| 7th-8th     | 4           | Married-civ-spouse| Craft-repair     | Husband      | White| Male  | 0          | 0          | 10           | United-States| <=50K|2        |0.0        |0.0     |1.0            |8.0           |0.0           |2.0           |[0.0,1.0,8.0,0.0,2.0] |[20340.0,4014.0]|[0.8351810790835181,0.1648189209164819] |0.0       |
# |65 | Private         | 184454| HS-grad     | 9           | Married-civ-spouse| Machine-op-inspct| Husband      | White| Male  | 6418       | 0          | 40           | United-States| >50K |2        |1.0        |0.0     |6.0            |0.0           |0.0           |2.0           |(5,[1,4],[6.0,2.0])   |[20340.0,4014.0]|[0.8351810790835181,0.1648189209164819] |0.0       |
# +---+-----------------+-------+-------------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+---------+-----------+--------+---------------+--------------+--------------+--------------+----------------------+----------------+----------------------------------------+----------+
# only showing top 10 rows

# %%
df_ = predictions

df_.createOrReplaceTempView('df_')

df_aciertos = spark.sql("""
    SELECT income, prediction, count(*)
    FROM df_
    GROUP BY 1, 2
""")

df_aciertos.show()
# Out:
# +------+----------+--------+
# |income|prediction|count(1)|
# +------+----------+--------+
# |  >50K|       1.0|    1109|
# | <=50K|       1.0|     535|
# | <=50K|       0.0|   11899|
# |  >50K|       0.0|    2737|
# +------+----------+--------+

# %%
# MATRIZ DE CONFUSION
import pandas as pd
pd.DataFrame([[1109, 535], [2737, 11899]], columns=['POSITIVO ACTUAL', 'NEGATIVO ACTUAL'], index = ['POSITIVO PREDECIDO', 'NEGATIVO PREDECIDO'])
# Out:
#                     POSITIVO ACTUAL  NEGATIVO ACTUAL
# POSITIVO PREDECIDO             1109              535
# NEGATIVO PREDECIDO             2737            11899

# %% [markdown]
# 4. Graficar la curva ROC utilizando los datos de validación (sin usar el paquete de evluación de Spark pyspark.ml.evaluation)

# %%
trainingData = df_adult_bucketized
testData = df_test_bucketized

# %%
def get_tpr_and_fpr(prediction):
    
    df_ = predictions

    df_.createOrReplaceTempView('df_')

    df_aciertos = spark.sql("""
        SELECT income, prediction, count(*) as count
        FROM df_
        GROUP BY 1, 2
    """)
    
    tp = df_aciertos.where('income = " >50K" and prediction = 1.0').first()['count'] if df_aciertos.where('income = " >50K" and prediction = 1.0').count() > 0 else 0
    
    fn = df_aciertos.where('income = " >50K" and prediction = "0.0"').first()['count'] if df_aciertos.where('income = " >50K" and prediction = "0.0"').count() > 0 else 0
    
    
    fp = df_aciertos.where('income = " <=50K" and prediction = 1.0').first()['count'] if df_aciertos.where('income = " <=50K" and prediction = 1.0').count() > 0 else 0
    
    
    tn = df_aciertos.where('income = " <=50K" and prediction = 0.0').first()['count'] if df_aciertos.where('income = " <=50K" and prediction = 0.0').count() > 0 else 0
    
        
    tpr = tp/(tp + fn)
    
    fpr = fp/(tn + fp)
    
    return (tpr, fpr)

# %%
get_tpr_and_fpr(predictions)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-5cde797cbcda> in <module>
# ----> 1 get_tpr_and_fpr(predictions)
#
# <ipython-input-37-02ac093b5424> in get_tpr_and_fpr(prediction)
#      19
#      20
# ---> 21     tn = df_aciertos.where('income = " <=50K" and prediction = 0.0').first()['count'] if df_aciertos.where('income = " <=50K" and prediction = 0.0').count() > 0 else 0
#      22
#      23
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pyspark\sql\dataframe.py in count(self)
#     662         2
#     663         """
# --> 664         return int(self._jdf.count())
#     665
#     666     def collect(self):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1301             proto.END_COMMAND_PART
#    1302
# -> 1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\py4j\java_gateway.py in send_command(self, command, retry, binary)
#    1031         connection = self._get_connection()
#    1032         try:
# -> 1033             response = connection.send_command(command)
#    1034             if binary:
#    1035                 return response, self._create_connection_guard(connection)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\py4j\java_gateway.py in send_command(self, command)
#    1198
#    1199         try:
# -> 1200             answer = smart_decode(self.stream.readline()[:-1])
#    1201             logger.debug("Answer received: {0}".format(answer))
#    1202             if answer.startswith(proto.RETURN_MESSAGE):
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
thresholds = range(0, 105, 5)

values = []

for t in thresholds:
    t = t/100
    print(t)
    
    pipeline = get_pipeline(thresholds=[1-t, t])
    
    model = pipeline.fit(trainingData)
    
    predictions = model.transform(testData)
    
    tpr, fpr = get_tpr_and_fpr(predictions)
    
    values.append([t, [tpr, fpr]])

# %%
values

# %%
df = pd.DataFrame([(p,tpr,fpr) for (p,(tpr,fpr)) in values], columns=['p', 'tpr', 'fpr'])

# %%
df.plot(style='.-',x='fpr',y='tpr', 
        title="ROC (Receiver Operating Characteristic) Curve")

# %% [markdown]
# 5. Escribir dos funciones train() y predict() que creen el arbol de acuerdo a la metodología vista en clase (utilizando entropía como métrica de homogeneidad de clases).
# ```
# def train(train_dataframe):
#     '''
#     @return devuelve una estructura de datos que representa el árbol de decision
#     '''
#      pass
# ```
#
# ```
# def predict(tree, train_dataframe)
#     '''
#     @param tree la estructura de datos que representa el árbol de decisión.
#     @ return un dataframe con todos los datos de train_dataframe con una columna adicional que representa la probabilidad de que el income sea >50K.
#     '''
#     pass
# ```
# Ejemplo de uso:
#
# ```
# tree = train(train_dataframe)
# predictions_df = predict(tree, train_dataframe)
# ```

# %%
import math
def entropy(probabs):
    return -sum([ p * math.log(p,2) for p in probabs if p != 0])

# %%
def get_feature_entropy(df, col):
    """Calculamos la entropy de una columna"""
    
    ncol = df.select(col).distinct().collect()
    ncol = [row[col] for  row in ncol]
    
    total = df.count()
    
    prob_valor = {}
    
    entropy_valor = {}
    
    for valor in ncol:
        ntmp = df.select(col).where(f'{col} = "{valor}"').count()
        
        prob_valor[valor] = ntmp/total
        
        ntmp_pos = df.select(col).where(f'{col} = "{valor}" and income = " >50K"').count()
        
        prob_pos = ntmp_pos/ntmp
        
        prob_neg = 1 - prob_pos
        
        entropy_ = entropy([prob_pos, prob_neg])
        
        entropy_valor[valor] = entropy_
    
    suma_ponderada = 0
    
    for valor in ncol:
        suma_ponderada += prob_valor[valor] * entropy_valor[valor]
    
    return suma_ponderada

# %%
def make_split(df, root, categorias):
    
    print(vars(root))
    
    if len(categorias) == 0:
        
        c1 = df.select('income').where('income = " >50K"').count()
        
        c2 = df.select('income').where('income =  " <=50K"').count()
        
        print(c1, c2)
        
        root.prediccion = ">50K" if c1>c2 else "<=50K"
        
        return
    
    categoria_entropy = {}
    
    for categoria in categorias:
        categoria_entropy[categoria] = get_feature_entropy(df, categoria)
        
    categoria_minima = min(categoria_entropy, key=categoria_entropy.get)
    
    valores_categoria = [valores[categoria_minima] for valores in df.select(categoria_minima).distinct().collect()]
    
    for valor in valores_categoria:
        
        root.hijos[valor] = Nodo(valor=valor, padre=root, columna_hijos=categoria_minima)
        
        df_ = df.where(f'{categoria_minima} = "{valor}"').drop(categoria_minima)
        
        categorias_aux = categorias.copy()
        categorias_aux.remove(categoria_minima)
        
        make_split(df_, root.hijos[valor], categorias_aux)

# %%
class Nodo:
    def __init__(self, valor, padre, prediccion=None, hijos=None, columna_hijos = None):
        self.valor = valor
        
        if padre == 'root':
            self.padre = None
        else:
            self.padre = padre
        
        self.hijos = {} if not hijos else hijos
        
        self.columna_hijos = columna_hijos
        
        self.prediccion = prediccion

# %%
def train(train_dataframe, columns=["sex", "occupation", "education", "workclass", "ageBucket"]):
     '''
     @return devuelve una estructura de datos que representa el árbol de decision
     '''
        
    arbol = Nodo(None, 'root')
    make_split(df=train_dataframe, root=arbol, categorias=train_dataframe.columns)
    
    return arbol

# %%
#make_split(df=df_adult_bucketized, root=arbol, categorias=["sex", "occupation", "education", "workclass", "ageBucket"])
make_split(df=df_adult_bucketized, root=arbol, categorias=["education", "occupation"])
# Out:
# {'valor': None, 'padre': None, 'hijos': {}, 'prediccion': None}
# {'valor': ' Prof-school', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 1 3
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 348 104
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 4 5
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 38 14
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 5 2
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 11 7
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 8 10
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 3 4
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 3 0
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 1 0
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 0 1
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B73FCD8940>, 'hijos': {}, 'prediccion': None}
# 1 3
# {'valor': ' 10th', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 1 43
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 2 69
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 3 6
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 0 38
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 6 18
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 19 151
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 4 77
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 2 100
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 1 2
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 17 67
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 0 6
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 6 95
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 1 193
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B756BE3340>, 'hijos': {}, 'prediccion': None}
# 0 6
# {'valor': ' 7th-8th', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 5 65
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 0 46
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 0 9
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 1 10
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 6 13
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 8 108
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 4 25
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 2 71
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 0 5
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 7 53
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 0 9
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 6 87
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 1 97
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B7402958E0>, 'hijos': {}, 'prediccion': None}
# 0 8
# {'valor': ' 5th-6th', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 0 36
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 2 38
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 0 1
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 0 6
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 1 0
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 3 40
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 3 9
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 2 28
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 0 1
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 2 26
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 0 1
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 3 53
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 0 64
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B756BD1220>, 'hijos': {}, 'prediccion': None}
# 0 14
# {'valor': ' Assoc-acdm', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 3 11
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 2 22
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 37 101
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 30 163
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 66 79
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 32 83
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 39 105
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 6 41
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 20 53
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 3 24
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 12 22
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 9 24
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 6 72
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B756B80DF0>, 'hijos': {}, 'prediccion': None}
# 0 2
# {'valor': ' Assoc-voc', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 9 43
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 2 26
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 59 111
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 18 149
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 64 86
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 81 171
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 27 79
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 13 48
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 37 89
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 11 29
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 17 31
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 14 49
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 9 106
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B756C190D0>, 'hijos': {}, 'prediccion': None}
# 0 4
# {'valor': ' Masters', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 3 7
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 0 5
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 419 425
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 23 45
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 372 129
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 10 12
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 80 54
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 18 30
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 20 17
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 4 6
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 7 8
# {'valor': ' Armed-Forces', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 1 0
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 1 7
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 1 18
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B74056BD30>, 'hijos': {}, 'prediccion': None}
# 0 1
# {'valor': ' 12th', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 0 16
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 2 36
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 2 8
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 1 37
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 2 11
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 9 49
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 5 42
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 2 38
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 1 2
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 7 32
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 0 6
# {'valor': ' Armed-Forces', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 0 1
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 1 34
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 1 84
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B756C26970>, 'hijos': {}, 'prediccion': None}
# 0 4
# {'valor': ' Preschool', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756C1D580>, 'hijos': {}, 'prediccion': None}
# 0 9
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B756C1D580>, 'hijos': {}, 'prediccion': None}
# 0 2
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756C1D580>, 'hijos': {}, 'prediccion': None}
# 0 1
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B756C1D580>, 'hijos': {}, 'prediccion': None}
# 0 2
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756C1D580>, 'hijos': {}, 'prediccion': None}
# 0 4
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756C1D580>, 'hijos': {}, 'prediccion': None}
# 0 5
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756C1D580>, 'hijos': {}, 'prediccion': None}
# 0 11
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756C1D580>, 'hijos': {}, 'prediccion': None}
# 0 15
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B756C1D580>, 'hijos': {}, 'prediccion': None}
# 0 2
# {'valor': ' 9th', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 1 27
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 3 46
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 0 3
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 1 13
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 2 11
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 7 89
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 4 28
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 1 50
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 0 2
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 3 32
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 0 4
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 3 73
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 2 99
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B756C042E0>, 'hijos': {}, 'prediccion': None}
# 0 10
# {'valor': ' Bachelors', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 21 56
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 11 39
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 579 916
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 119 386
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 779 590
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 88 138
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 382 427
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 45 128
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 78 152
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 15 47
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 56 44
# {'valor': ' Armed-Forces', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 0 1
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 18 51
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 29 152
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B755A1BD90>, 'hijos': {}, 'prediccion': None}
# 1 6
# {'valor': ' Doctorate', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756C3A280>, 'hijos': {}, 'prediccion': None}
# 1 0
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756C3A280>, 'hijos': {}, 'prediccion': None}
# 233 88
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B756C3A280>, 'hijos': {}, 'prediccion': None}
# 2 3
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B756C3A280>, 'hijos': {}, 'prediccion': None}
# 50 5
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756C3A280>, 'hijos': {}, 'prediccion': None}
# 1 1
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B756C3A280>, 'hijos': {}, 'prediccion': None}
# 5 3
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756C3A280>, 'hijos': {}, 'prediccion': None}
# 11 4
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B756C3A280>, 'hijos': {}, 'prediccion': None}
# 1 2
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B756C3A280>, 'hijos': {}, 'prediccion': None}
# 0 1
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756C3A280>, 'hijos': {}, 'prediccion': None}
# 1 0
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756C3A280>, 'hijos': {}, 'prediccion': None}
# 1 0
# {'valor': ' HS-grad', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 47 357
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 38 573
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 60 173
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 163 1202
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 261 546
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 405 1517
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 200 869
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 46 487
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 47 112
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 168 657
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 47 168
# {'valor': ' Armed-Forces', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 0 4
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 140 883
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 53 1228
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B756B97910>, 'hijos': {}, 'prediccion': None}
# 0 50
# {'valor': ' 11th', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 2 35
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 5 118
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 2 18
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 3 64
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 7 27
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 18 157
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 5 139
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 0 119
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 0 6
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 7 85
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 2 5
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 3 96
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 6 232
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B756C52520>, 'hijos': {}, 'prediccion': None}
# 0 14
# {'valor': ' Some-college', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 20 154
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 19 248
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 117 313
# {'valor': ' Adm-clerical', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 142 1139
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 312 567
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 241 627
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 214 795
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 35 481
# {'valor': ' Tech-support', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 75 198
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 73 210
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 69 133
# {'valor': ' Armed-Forces', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 0 2
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 44 266
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 26 755
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B756C41880>, 'hijos': {}, 'prediccion': None}
# 0 16
# {'valor': ' 1st-4th', 'padre': <__main__.Nodo object at 0x000001B756BD59D0>, 'hijos': {}, 'prediccion': None}
# {'valor': ' Farming-fishing', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 1 17
# {'valor': ' Handlers-cleaners', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 0 16
# {'valor': ' Prof-specialty', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 0 4
# {'valor': ' Exec-managerial', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 2 2
# {'valor': ' Craft-repair', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 2 21
# {'valor': ' Sales', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 0 8
# {'valor': ' ?', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 0 12
# {'valor': ' Transport-moving', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 0 8
# {'valor': ' Protective-serv', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 0 1
# {'valor': ' Machine-op-inspct', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 1 22
# {'valor': ' Other-service', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 0 40
# {'valor': ' Priv-house-serv', 'padre': <__main__.Nodo object at 0x000001B756D53A60>, 'hijos': {}, 'prediccion': None}
# 0 11

# %%
arbol.__dict__
# Out:
# {'valor': None,
#  'padre': None,
#  'hijos': {' Prof-school': <__main__.Nodo at 0x1b73fcd8940>,
#   ' 10th': <__main__.Nodo at 0x1b756be3340>,
#   ' 7th-8th': <__main__.Nodo at 0x1b7402958e0>,
#   ' 5th-6th': <__main__.Nodo at 0x1b756bd1220>,
#   ' Assoc-acdm': <__main__.Nodo at 0x1b756b80df0>,
#   ' Assoc-voc': <__main__.Nodo at 0x1b756c190d0>,
#   ' Masters': <__main__.Nodo at 0x1b74056bd30>,
#   ' 12th': <__main__.Nodo at 0x1b756c26970>,
#   ' Preschool': <__main__.Nodo at 0x1b756c1d580>,
#   ' 9th': <__main__.Nodo at 0x1b756c042e0>,
#   ' Bachelors': <__main__.Nodo at 0x1b755a1bd90>,
#   ' Doctorate': <__main__.Nodo at 0x1b756c3a280>,
#   ' HS-grad': <__main__.Nodo at 0x1b756b97910>,
#   ' 11th': <__main__.Nodo at 0x1b756c52520>,
#   ' Some-college': <__main__.Nodo at 0x1b756c41880>,
#   ' 1st-4th': <__main__.Nodo at 0x1b756d53a60>},
#  'prediccion': None}

# %%
def imprimir_arbol(arbol, tab):
    
    if arbol.prediccion is None:
        print('|', tab*'►', arbol.valor)
        for _, hijo in arbol.hijos.items():
            imprimir_arbol(hijo, tab+1)
    else:
        print('|', tab*'--', arbol.valor, '►', arbol.prediccion)

# %%
imprimir_arbol(arbol, 0)
# Out:
# |  None
# | ►  Prof-school
# | ----  Farming-fishing ► <=50K
# | ----  Prof-specialty ► >50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► >50K
# | ----  Craft-repair ► >50K
# | ----  Sales ► >50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► >50K
# | ----  Protective-serv ► >50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ►  10th
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► <=50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  7th-8th
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► <=50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  5th-6th
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► >50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  Assoc-acdm
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► <=50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  Assoc-voc
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► <=50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  Masters
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► >50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► >50K
# | ----  ? ► <=50K
# | ----  Tech-support ► >50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Armed-Forces ► >50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  12th
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► <=50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Armed-Forces ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  Preschool
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Craft-repair ► <=50K
# | ----  ? ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  9th
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► <=50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  Bachelors
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► >50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► >50K
# | ----  Armed-Forces ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  Doctorate
# | ----  Farming-fishing ► >50K
# | ----  Prof-specialty ► >50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► >50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► >50K
# | ----  ? ► >50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Machine-op-inspct ► >50K
# | ----  Other-service ► >50K
# | ►  HS-grad
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► <=50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Armed-Forces ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  11th
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► <=50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  Some-college
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Adm-clerical ► <=50K
# | ----  Exec-managerial ► <=50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Tech-support ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Armed-Forces ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K
# | ►  1st-4th
# | ----  Farming-fishing ► <=50K
# | ----  Handlers-cleaners ► <=50K
# | ----  Prof-specialty ► <=50K
# | ----  Exec-managerial ► <=50K
# | ----  Craft-repair ► <=50K
# | ----  Sales ► <=50K
# | ----  ? ► <=50K
# | ----  Transport-moving ► <=50K
# | ----  Protective-serv ► <=50K
# | ----  Machine-op-inspct ► <=50K
# | ----  Other-service ► <=50K
# | ----  Priv-house-serv ► <=50K

# %%
def predict(tree, train_dataframe, columns=["sex", "occupation", "education", "workclass", "ageBucket"])
    '''
    @param tree la estructura de datos que representa el árbol de decisión.
    @ return un dataframe con todos los datos de train_dataframe con una columna adicional que representa la probabilidad de que el income sea >50K. 
    '''
    
    def predict_udf(tree, **kwargs):
        
        for key, value in kwargs:
            
            tree.hijos[key]
        
    
    F.udf(  )

# %%
a={'v': 1, 'a': 3}
print(*a)
print(v, a)
# Out:
# v a

# %%
df = pd.read_csv('.arbol')
vars(df['arbol'].item())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-08179ae82b3c> in <module>
#       1 df = pd.read_csv('.arbol')
# ----> 2 vars(df['arbol'].item())
#
# TypeError: vars() argument must have __dict__ attribute

# %% [markdown]
# <i>[Extra credit y alumnos masters]</i>
#
# 5.  Mejorar la implementación de su algoritmo evitando hacer el split cuando no se logra un mínimo de Information Gain ( https://en.wikipedia.org/wiki/Information_gain_in_decision_trees   )

# %%
#
